# %% [markdown]
# # Inference notebook for MD-SEM

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy
import os
import sys
sys.path.append('../src')
from multiduration_models import xception_se_lstm

# %% [markdown]
# ## Load model ##

# %%
shape_r = 240
shape_c = 320
n_outs_model = 3
loaded_model = xception_se_lstm(input_shape = (shape_r,shape_c,3), n_outs = n_outs_model, ups=16, verbose=False)

load_weights = True

base_ckpt_path = '../ckpt'

Wb = "mdsem_codecharts0_cameraready_weights.hdf5"

W =  os.path.join(base_ckpt_path, Wb)

if load_weights:
    loaded_model.load_weights(W)
# Out:
# xception output shapes: (?, 30, 40, 2048)
# shape after AvgPool (?, 3, 2048)
# shape after first dense (?, 3, 512)
# shape after lstm (?, 3, 512)
# shape after second dense: (?, 3, 2048)
# shape before mult (?, 3, 1, 1, 2048)
# shape out (?, 3, 30, 40, 2048)
# Shape after last ups: (?, 3, 480, 640, 64)
# Shape after 1x1 conv: (?, 3, 480, 640, 1)

# %% [markdown]
# ## Inspect model ##

# %%
loaded_model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_5 (InputLayer)            (None, 240, 320, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 119, 159, 32) 864         input_5[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 119, 159, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 119, 159, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# ...

# %% [markdown]
# ## Helper functions for pre-processing images prior to evaluation ##

# %%
def padding(img, shape_r, shape_c, channels=3):
    img_padded = np.zeros((shape_r, shape_c, channels), dtype=np.uint8)
    if channels == 1:
        img_padded = np.zeros((shape_r, shape_c), dtype=np.uint8)

    original_shape = img.shape
    rows_rate = original_shape[0]/shape_r
    cols_rate = original_shape[1]/shape_c

    if rows_rate > cols_rate:
        new_cols = (original_shape[1] * shape_r) // original_shape[0]
        img = cv2.resize(img, (new_cols, shape_r))
        if new_cols > shape_c:
            new_cols = shape_c
        img_padded[:, ((img_padded.shape[1] - new_cols) // 2):((img_padded.shape[1] - new_cols) // 2 + new_cols)] = img
    else:
        new_rows = (original_shape[0] * shape_c) // original_shape[1]
        img = cv2.resize(img, (shape_c, new_rows))
        if new_rows > shape_r:
            new_rows = shape_r
        img_padded[((img_padded.shape[0] - new_rows) // 2):((img_padded.shape[0] - new_rows) // 2 + new_rows), :] = img

    return img_padded

def preprocess_images(paths, shape_r, shape_c):
    ims = np.zeros((len(paths), shape_r, shape_c, 3))

    for i, path in enumerate(paths):
        original_image = cv2.imread(path)
        padded_image = padding(original_image, shape_r, shape_c, 3)
        ims[i] = padded_image

    ims[:, :, :, 0] -= 103.939
    ims[:, :, :, 1] -= 116.779
    ims[:, :, :, 2] -= 123.68

    return ims


def reverse_preprocess(img):
    im = deepcopy(img)

    im[:, :, 0] += 103.939
    im[:, :, 1] += 116.779
    im[:, :, 2] += 123.68

    im = im[...,::-1]

    im = np.array(im, dtype=np.uint8)

    return im

# %% [markdown]
# ## Evaluate loaded model on a few sample images ##

# %%
model_inp_size = (240, 320)
image_path = "../images"
imgs = [os.path.join(image_path, f) for f in os.listdir(image_path)]
images = preprocess_images(imgs, model_inp_size[0], model_inp_size[1])

# %%
preds_mdsem = loaded_model.predict(images)

# %%
print(preds_mdsem.shape)
# Out:
# ----------------------------------------
# AttributeErrorTraceback (most recent call last)
# <ipython-input-26-b6317eca2600> in <module>
# ----> 1 print(preds_mdsem.shape)
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
# NOTE: the model output has a dimension for which viewing duration to predict (for a total of 3 durations)
# if you only want to use a single viewing duration, use the 3000 ms duration (which is at index 1) 
# which corresponds to viewing durations in standard saliency datasets

times = [500, 3000, 5000] 
ntimes = len(times)

for i in range(len(images)):
    plt.figure(figsize = (14,8))
    # Plot maps for each timestep
    for t in range(ntimes):
        plt.subplot(ntimes,2,t*2+1)
        plt.imshow(reverse_preprocess(images[i]))
        plt.axis('off')
        plt.title(imgs[i])
        plt.subplot(ntimes,2,t*2+2)
        plt.imshow(preds_mdsem[0][i,t,:,:,0]) 
        plt.axis('off')
        plt.title(str(times[t])+'ms')
